# %% [markdown]
# ## Flowcharts
#
# Using what we've learned about flowcharts, complete the following exercises

# %% [markdown]
# <div class="alert alert-block alert-info">
# For the following exercises, write Python code that does what each flowchart indicates in the code cells immediately below them. Feel free to add <code>input()</code> statements with prompts, as well as <code>print()</code> statements that print output to the notebook when you run the cell. <br>
#
# <b>For each exercise</b>, be sure to run the indicated test cases. <b>For each case you run</b>, select the lines of output, copy them (<code>CTRL-C</code>), paste them (<code>CTRL-V</code>) into the bottom of your code cell, then select those lines and comment them out (<code>CTRL-/</code>). This provides evidence that you actually ran these test cases. Make sure they each give you the expected result.
# </div>

# %% [markdown]
# ### 1. Dividing Numbers

# %% [markdown]
# ![Screenshot 2026-03-24 at 10.03.30 PM.png](attachment:92c39ffe-8ad3-419f-9e7f-c74a178c9cb0.png)

# %%
# Write Your Code Here for Division Flowchart (see above)
print("enter a, b and operator: ")
a = int(input("input a : "))
b = int(input("input b : "))
c = input("input operator(+, -, *, / : ")
if(b == 0) :
    print("division by 0 is illegal")
elif(c == "+"):
    q = a + b
    print("a + b = ", q)
elif(c == "-"):
    q = a - b
    print("a - b = ", q)
elif(c == "*"):
    q = a * b
    print("a * b = ", q)
elif(c == "/"):
    q = a / b
    print("a / b = ", q)
# run two test cases: divide non-zero by non-zero, divide non-zero by zero
# copy the output and paste it into the bottom of your code cell
# enter a and b:
# a / b =  0.5
# enter a and b:
# division by 0 is illegal
# Extra challenge: Write a program that prompts user for operator (+, -, *, /), asks the user
# to enter two numbers, then reports the result of the calculation.
# The flowchart above shows the special case of division (don't allow division by zero)
# Out:
# enter a b and operator:
# a + b =  7

# %% [markdown]
# ### 2. Leap Year

# %% [markdown]
# ![Screenshot 2026-03-24 at 10.03.24 PM.png](attachment:e2fe6d53-2081-42b2-beb1-46e68ca926e5.png)

# %%
# Write Your Code Here for leap year flowchart (see above)
a = int(input("input year : "))
if(a % 400 == 0) :
  print(a, " is a leap year")
elif(a % 100 == 0):
  print(a, " is not a leap year")
elif(a % 4 == 0):
    print(a, " is a leap year")
else :
    print(a, " is not a leap year")
# if year is divisible by 400, then it's a leap year (2000 was a leap year!)
# if year is divisible by 100, it's not a leap year
# if year is divisible by 4, it's a leap year

# see https://www.rmg.co.uk/stories/topics/which-years-are-leap-years-can-you-have-leap-seconds
# solar year is 365.2422 days: add 1 day every 4 years: +0.25; lose 1 day every 100 years: -0.01;
# add 1 day back every 400 years: +0.0025

# x % y = 0 means that x is divisible by y (e.g., n % 2 = 0 if n is even, while n % 2 = 1 if n is odd)

# run your code with these test cases: 2023 (not a leap year); 2024 (leap year); 1900 (not a leap year); 2000 (leap year)
# copy the output and paste it into the bottom of your code cell
# 2023  is not a leap year
# #2024  is a leap year
# 1900  is not a leap year
# 2000  is a leap year
# Out:
# 2000  is a leap year

# %% [markdown]
# ### 3. Temperature Conversion

# %% [markdown]
# ![Screenshot 2026-03-24 at 10.03.39 PM.png](attachment:490f0d87-1c65-4afa-ae63-87bb4aa2252c.png)

# %%
# Write Your Code Here for F to C, C to F flowchart (see above)
a = int(input("1 for f to c, press 2 c to f "))
if(a == 1) :
    Tf = int(input("enter fahrenheit temp : "))
    Tc = (Tf - 32) *5/9
    print("Fahrenheit temp is ", Tc, " celsius")
elif(a == 1) :
    Tf = int(input("enter fahrenheit temp : "))
    Tc = (Tf - 32) *5/9
    print("Celsius temp is ", Tc, " fahrenheit")
else : print("you need to put in one of two numbers how did you screw that up")
# run your code with three test cases (known values: 0°C = 32°F; 100°C = 212°F; -40°C = -40°F)
# copy the output and paste it into the bottom of your code cell

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### If you get to this point BEFORE class is over...
# ### **Code to Flowcharts**
#
# Navigate to the link below , which is a website you can use to make your own flowchart, or a google slide/drawing. Convert the code below to a flowchart, and attach a screenshot, .png, or .jpg of your resulting chart to the Google Classroom assignment (along with this notebook)
#
# The site allows you to drag and drop blocks in, and connect blocks with arrows. If you double-click a block, it will allow you to add text! You are also able to change the color, size, etc., of the blocks.
#
# #### Link to example site: [click here](https://app.smartdraw.com/?nsu=1&_gl=1*12cnvgn*_ga*MTcwOTQ0NzM0MS4xNzc0Mjg2MTAy*_ga_9796Z3R0VG*czE3NzQzNzAwNTgkbzIkZzAkdDE3NzQzNzAwNTgkajYwJGwwJGgw*_gcl_au*MTY5ODkwOTExMi4xNzc0Mjg2MTAz*_ga_27Q2KCD9PF*czE3NzQzNzAwNTgkbzIkZzAkdDE3NzQzNzAwNTgkajYwJGwwJGgw)
#
# </div>

# %%
# Code to convert to flowchart:
# Grading System

score = int(input("Enter your test score (0-100): "))
late = input("Was the assignment late? (yes/no): ")

# Determine letter grade
if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 60:
    grade = "D"
else:
    grade = "F"

# BONUS ADDITION --> Late penalty
if late == "yes":
    if grade == "A":
        grade = "B"
    elif grade == "B":
        grade = "C"
    elif grade == "C":
        grade = "D"
    elif grade == "D":
        grade = "F"

print("Final grade:", grade)
